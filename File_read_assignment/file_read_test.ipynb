# %%
import math
def opener(test_file):
    with open(test_file) as file_ptr:
        return file_ptr.read()

def palindrome(my_file):
    data = opener(my_file)
    palin_tuple = tuple()
   # print(data.split(r'\n'))
    for search in data.split(r'\n'):
       # print(data.split('\n')[0])
        for sub_search in search.split(' '):
          final_search = 0
          error_l = 0
          error_r = 0
          if len(sub_search)!=0:
            while final_search <= len(sub_search)//2:
            
                print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                if sub_search[final_search + error_l].isalpha() and sub_search[len(sub_search) - final_search - 1 - error_r].isalpha():
                    print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                    
                    if sub_search[final_search + error_l] == sub_search[len(sub_search) - final_search - 1 - error_r]:
                        final_search += 1
                        continue
                    else:
                        break
                elif sub_search[final_search] == "'" or sub_search[len(sub_search) - final_search - 1] == "'":
                    break
                else:
                    if not sub_search[final_search].isalpha():
                        error_l += 1
                        print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                        
                        if sub_search[final_search + error_l ] == sub_search[len(sub_search) - final_search - 1 + error_r]:
                            final_search += 1
                            continue
                        else:
                           break
                    else:
                        error_r -= 1
                        print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                        
                        if sub_search[final_search + error_l ] == sub_search[len(sub_search) - final_search - 1 + error_r]:
                            final_search += 1
                            continue
                        else:
                            break
            else:
                list(palin_tuple).append(sub_search)
    return palin_tuple
print(palindrome('testfile.txt'))
# Out:
# 0 8 8 Building,
# 0 7 8 Building,
# 0 1 1 on
# 0 1 1 on
# 0 3 3 Part
# 0 3 3 Part
# 0 0 0 1
# 1 0 0 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 52
#      50                 list(palin_tuple).append(sub_search)
#      51     return palin_tuple
# ---> 52 print(palindrome('testfile.txt'))
#
# Cell In[8], line 35, in palindrome(my_file)
#      32 error_l += 1
#      33 print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
# ---> 35 if sub_search[final_search + error_l ] == sub_search[len(sub_search) - final_search - 1 + error_r]:
#      36     final_search += 1
#      37     continue
#
# IndexError: string index out of range

# %%
import re
escape_characters = [
    r"\n",      # Newline
    r"\t",       # Horizontal tab
    r"\\",       # Backslash
    r"\'",       # Single quote
    r"\"",       # Double quote
    r"\r",       # Carriage return
    r"\b",       # Backspace
    r"\f",       # Form feed
    r"\a",       # Bell/Alert
    r"\v",       # Vertical tab
    r"\0",       # Null character
    r"\x20",     # Hexadecimal (space character as example)
    r"\041",     # Octal value (exclamation mark as example)
    r"\u00A9",   # 16-bit Unicode (copyright symbol as example)
    r"\U0001F600" # 32-bit Unicode (grinning face emoji as example)
]

with open('testfile.txt') as fp:
    data = fp.read()
    l = []
    l = list(set([ x for x in data if not x.isalpha()]))
    l+= list(set([ y for y in data if y in escape_characters]))
    print(l)
    result = re.split(r'[{}]+'.format(''.join(l)+''.join(escape_characters)),data)
    print(result)
    
          
            
#result = re.split(r'[,\n\t\s-]+', text)
#print(result)  # Output: ['apple', 'banana', 'pear', 'orange']
# Out:
# [')', '1', '5', '6', '\\', '0', '2', '-', '!', '.', '’', ',', '\n', '(', ' ', '8']
# ...

# %%
import math
def opener(test_file):
    with open(test_file) as file_ptr:
        return file_ptr.readlines()
        
def palindrome(my_file):
    data = opener(my_file)
    palin_tuple = tuple()
   # print(data.split(r'\n'))
    for search in data:
       # print(data.split('\n')[0])
        for sub_search in search.split(' '):
          final_search = 0
          error_l = 0
          error_r = 0
          if len(sub_search)!=0:
            while final_search <= len(sub_search)//2:
            
                print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                if sub_search[final_search + error_l].isalpha() and sub_search[len(sub_search) - final_search - 1 - error_r].isalpha():
                    print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                    
                    if sub_search[final_search + error_l] == sub_search[len(sub_search) - final_search - 1 - error_r]:
                        final_search += 1
                        continue
                    else:
                        break
                elif sub_search[final_search] == "'" or sub_search[len(sub_search) - final_search - 1] == "'":
                    break
                else:
                    if not sub_search[final_search].isalpha():
                        error_l += 1
                        print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                        
                        if sub_search[final_search + error_l ] == sub_search[len(sub_search) - final_search - 1 - error_r]:
                            final_search += 1
                            continue
                        else:
                           break
                    else:
                        error_r -= 1
                        print(final_search + error_l , len(sub_search) - final_search - 1 + error_r,len(sub_search)-1,sub_search)
                        
                        if sub_search[final_search + error_l ] == sub_search[len(sub_search) - final_search - 1 + error_r]:
                            final_search += 1
                            continue
                        else:
                            break
            else:
                list(palin_tuple).append(sub_search)
    return palin_tuple
print(palindrome('testfile.txt'))

# %%
def opener(test_file):
    with open(test_file) as file_ptr:
        return file_ptr.readlines()
opener('testfile.txt')
# Out:
# ['\\nBuilding, on Part 1 of this PSF Grants Program Update, we are pleased to share updates to the Grants Workgroup (workgroup) Charter. We have outlined all the changes below in a chart, but there are a couple of changes that we’d like to highlight to grant applicants. These updates in particular will change how and when you apply, and hopefully reduce blockers to getting those applications in and ready for review. Because we are just sharing these updates, we are happy to be flexible on these changes but hope to see all applicants adhere to the changes starting around January 2025. \\n\\nIncrease overall process time frame to 8 weeks (formerly 6 weeks). We want to be realistic about how long the process takes and we know that going over our projection can cause pain for applicants. We hope to turn around applications in 6 weeks in most cases, but planning for the extra two weeks can make a big difference for everyone involved!\\nOur application form requires that you set the event 
# ...

# %%
def palindrome(my_string):
    for search in range(0, len(my_string)//2, 1):
        if my_string.lower()[search] == my_string.lower()[-1 - search]:
            continue
        else:
            return "Given string is not a palindrome."
    else:
        return "Given string is a palindrome."
palindrome('tacocat')
# Out:
# 'Given string is a palindrome.'

# %%
sub_scan = 'racecar8'

palin_list = []
end_pos , sub_scan = 0 , sub_scan+'-'
l = len(sub_scan)-1 # l = 4 
for char in range(len(sub_scan)):
    #char is 0 - 4
    if not sub_scan[char].isalpha():
        
        if end_pos != char:
            print(sub_scan[char],char)
            for cf in range(end_pos,char):
                if sub_scan[cf] == sub_scan[end_pos:char][char - 1 - cf]:
                
                    continue
                else:
                
                    break
            else:
            
                print(sub_scan[end_pos:char],'---------')
            
                palin_list.append(sub_scan[end_pos:char])
            
                print(palin_list)
            end_pos = char + 1
        elif end_pos == char:
            end_pos = char + 1
# Out:
# 8 7
# racecar ---------
# ['racecar']

# %%
def handler(func):
    def opener(incoming_file):
        try :
            with open(incoming_file) as file_ptr:
                f_content = file_ptr.read()
                func(f_content)
        except FileNotFoundError as error_msg :
            print('File {} is not found {} '.format(incoming_file,error_msg))
        except ValueError as error_msg :
            print('Please enter a valid filename {} and check if extension is "txt" or not error is {} '.format(incoming_file,error_msg))
        except Exception as error_msg :
            print('Error was - {} '.format(error_msg))
        else:
            print('Process executed successfully!')
        finally:
            file_ptr.close()
            print('Check file close status {} '.format(file_ptr.closed))
    return opener
@handler
def fetch_palindrome(f_data):
    try :
        f_data = (lambda text : text.split('\n'))(f_data)
        f_data = list(map(lambda sub_text : sub_text.split(),f_data))
    except Exception as error_msg:
        print('ERROR IS --> {} '.format(error_msg))

    else:
        try :
            palin_list = []
            if isinstance(f_data,list):
                for scan in f_data:
                    if isinstance(scan,list):
                        temp_scan = list(map(lambda rectifier : rectifier if any(letter.isalpha() for letter in rectifier) else '',scan))
                        for sub_scan in temp_scan:
                            if isinstance(sub_scan,str):
                                end_pos, sub_scan = 0, sub_scan + '-'
                                length = len(sub_scan) - 1
                                for char in range(len(sub_scan)):
                                    if not sub_scan[char].isalpha():
                                        if end_pos != char and char != length:
                                            print(sub_scan,scan)

                                            for cf in range(end_pos, char):
                                                if sub_scan[cf] == sub_scan[end_pos:char][char - 1 - cf]:
                                                    continue
                                                else:
                                                    break
                                            else:
                                                print(sub_scan,sub_scan[end_pos:char])
                                                palin_list.append(sub_scan[end_pos:char])
                                            end_pos = char + 1
                            else:
                                raise Exception('Something suspicious is included {} '.format(sub_scan))
                    elif isinstance(scan,str):
                        end_pos, scan = 0, scan + '-'
                        l = len(scan) - 1
                        for char in range(len(scan)):
                            if not scan[char].isalpha():
                                print(scan[end_pos:char], end_pos, char)
                                if end_pos != char and char != l:
                                    for cf in range(end_pos, char):
                                        if scan[cf] == scan[end_pos:char][char - 1 - cf]:
                                            continue
                                        else:
                                            break
                                    else:
                                        palin_list.append(scan[end_pos:char])
                                    end_pos = char + 1
                    else:
                        raise Exception('Something suspicious is included {} '.format(scan))
            else:
                raise Exception('Something suspicious is included {} '.format(f_data))
            return palin_list
        except Exception as error_msg:
            print('Error is --> {} '.format(error_msg))
       

print(fetch_palindrome('testfile.txt'))
# Out:
# \nBuilding,- ['\\nBuilding,', 'on', 'Part', '1', 'of', 'this', 'PSF', 'Grants', 'Program', 'Update,', 'we', 'are', 'pleased', 'to', 'share', 'updates', 'to', 'the', 'Grants', 'Workgroup', '(workgroup)', 'Charter.', 'We', 'have', 'outlined', 'all', 'the', 'changes', 'below', 'in', 'a', 'chart,but', 'there', 'are', 'a', 'couple', 'of', 'changes', 'that', 'we’d', 'like', 'to', 'highlight', 'to', 'grant', 'applicants.', 'These', 'updates', 'in', 'particular', 'will', 'change', 'how', 'and', 'when', 'you', 'apply,', 'and', 'hopefully', 'reduce', 'blockers', 'to', 'getting', 'those', 'applications', 'in', 'and', 'ready', 'for', 'review.', 'Because', 'we', 'are', 'just', 'sharing', 'these', 'updates,', 'we', 'are', 'happy', 'to', 'be', 'flexible', 'on', 'these', 'changes', 'but', 'hope', 'to', 'see', 'all', 'applicants', 'adhere', 'to', 'the', 'changes', 'starting', 'around', 'January', '2025.']
# ...

# %%
import re
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def handler(func):
    def opener(incoming_file):
        try :
            with open(incoming_file) as file_ptr:
                f_content = file_ptr.read()
                result = func(f_content)
        except FileNotFoundError as error_msg :
            print('File {} is not found {} '.format(incoming_file,error_msg))
        except ValueError as error_msg :
            print('Please enter a valid filename {} and check if extension is "txt" or not error is {} '.format(incoming_file,error_msg))
        except Exception as error_msg :
            print('Error was - {} '.format(error_msg))
        else:
            print('Process executed successfully!')
        finally:
            file_ptr.close()
            print('Check file close status {} '.format(file_ptr.closed))
            return result
    return opener

#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def palindrome(words,palin_list):
    try :
        end_pos, words = 0, words.lower().strip() + '--'
        length = len(words) - 1
        for char in range(len(words)):
            if not words[char].isalpha():
                if end_pos != char and char != length:
                    for cf in range(end_pos, char):
                        if words[cf] == words[end_pos:char][char - 1 - cf]:
                            continue
                        else:
                            break
                    else:
                        if len(words[end_pos:char]) > 1:
                            palin_list.append(words[end_pos:char])
                    end_pos = char + 1
                elif end_pos == char and not words[char].isalpha():
                    end_pos = char + 1
        return palin_list
    except Exception as error_msg:
        print('Error is {} '.format(error_msg))
    finally:
        return palin_list
    
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

@handler
def fetch_palindrome(f_data):
    try :
        palin_list = []
        f_data = (lambda text : text.split('\n'))(f_data)
        f_data = list(map(lambda sub_text : sub_text.split(),f_data))
    except Exception as error_msg:
        print('ERROR IS --> {} '.format(error_msg))
    else:
        try :
            if isinstance(f_data,list):
                for scan in f_data:
                    if isinstance(scan,list):
                        for sub_scan in scan:
                            if isinstance(sub_scan,str):
                                palin_list = palindrome(sub_scan,palin_list)
                            else:
                                raise Exception('Something suspicious is included {} '.format(sub_scan))
                    elif isinstance(scan,str):
                        palin_list = palindrome(scan, palin_list)
                    else:
                        raise Exception('Something suspicious is included {} '.format(scan))
            else:
                raise Exception('Something suspicious is included {} '.format(f_data))
        except Exception as error_msg:
            print('Error is --> {} '.format(error_msg))
        else:
            return palin_list
        
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

@handler
def fetch_palindrome_smartly(f_data):
    try :
        palin_list_eff = []
        escape_characters = [
        r"\n",  # Newline
        r"\t",  # Horizontal tab
        r"\\",  # Backslash
        r"\'",  # Single quote
        r"\"",  # Double quote
        r"\r",  # Carriage return
        r"\b",  # Backspace
        r"\f",  # Form feed
        r"\a",  # Bell/Alert
        r"\v",  # Vertical tab
        r"\0",  # Null character
        r"\x20",  # Hexadecimal (space character as example)
        r"\041",  # Octal value (exclamation mark as example)
        r"\u00A9",  # 16-bit Unicode (copyright symbol as example)
        r"\U0001F600"  # 32-bit Unicode (grinning face emoji as example)
        ]
        short_list = list(set([x for x in f_data if not x.isalpha()]))
        short_list += list(set([y for y in f_data if y in escape_characters]))
        result = re.split(r'[{}]+'.format(''.join(short_list) + ''.join(escape_characters)), f_data)
    except Exception as error_msg:
        print('ERROR in 1st try IS --> {} '.format(error_msg))
    else:
        try :
            if isinstance(result, list):
                for scan in result:
                    if scan[::-1] == scan and len(scan)!=1 and scan.isalpha():
                            palin_list_eff.append(scan)
            else:
                raise Exception('Something suspicious is included in file data {} '.format(result))
        except Exception as error_msg:
            print('Error in 2nd try is --> {} '.format(error_msg))
        else:
            return palin_list_eff

print(fetch_palindrome_smartly("obsu))
# Out:
# Process executed successfully!
# Check file close status True
# ['radar', 'level', 'kayak', 'civic', 'rotator', 'racecar', 'madam', 'refer', 'noon', 'pop', 'deed', 'peep', 'repaper', 'deed', 'rotor', 'stats', 'solos', 'tenet', 'deified', 'reviver', 'rotavator', 'tacocat', 'tacocat']

# %%
import re

# Decorator for handling file I/O and errors
def handler(func):
    def opener(incoming_file):
        try:
            with open(incoming_file) as file_ptr:
                f_content = file_ptr.read()
                result = func(f_content)
        except FileNotFoundError as error_msg:
            print(f'File {incoming_file} is not found: {error_msg}')
        except ValueError as error_msg:
            print(f'Please enter a valid filename "{incoming_file}" and check if extension is "txt": {error_msg}')
        except Exception as error_msg:
            print(f'Error occurred: {error_msg}')
        else:
            print('Process executed successfully!')
        finally:
            file_ptr.close()
            print(f'File close status: {file_ptr.closed}')
            return result
    return opener

# Utility function to check for palindromes
def is_palindrome(word):
    word = word.lower()
    return word == word[::-1] and len(word) > 1

# Modified fetch_palindrome_smartly to handle escape sequences as raw
@handler
def fetch_palindrome_smartly(f_data):
    try:
        # Convert backslashes in escape sequences like \n into raw strings
        f_data = f_data.replace(r"\n", "\\n").replace(r"\t", "\\t").replace(r"\\", "\\\\")
        
        # Split the text by non-alphabetic characters
        words = re.split(r'[^a-zA-Z]+', f_data)
        print(words)
        # Filter palindromic words
        palindromic_words = [word for word in words if is_palindrome(word)]
    except Exception as error_msg:
        print(f'Error: {error_msg}')
    else:
        return palindromic_words
print(fetch_palindrome_smartly('testfile.txt'))
# Out:
# ['', 'nBuilding', 'on', 'Part', 'of', 'this', 'PSF', 'Grants', 'Program', 'Update', 'radar', 'level', 'kayak', 'civic', 'rotator', 'racecar', 'madam', 'refer', 'noon', 'pop', 'deed', 'peep', 'repaper', 'deed', 'rotor', 'stats', 'solos', 'tenet', 'deified', 'reviver', 'rotavator', 'we', 'are', 'pleased', 'to', 'share', 'updates', 'to', 'the', 'Grants', 'Workgroup', 'workgroup', 'Charter', 'We', 'have', 'outlined', 'all', 'the', 'changes', 'below', 'in', 'a', 'chart', 'but', 'there', 'are', 'a', 'couple', 'of', 'changes', 'that', 'we', 'd', 'like', 'to', 'highlight', 'to', 'grant', 'applicants', 'These', 'updates', 'in', 'particular', 'will', 'change', 'how', 'and', 'when', 'you', 'apply', 'and', 'hopefully', 'reduce', 'blockers', 'to', 'getting', 'those', 'applications', 'in', 'and', 'ready', 'for', 'review', 'Because', 'we', 'are', 'just', 'sharing', 'these', 'updates', 'we', 'are', 'happy', 'to', 'be', 'flexible', 'on', 'these', 'changes', 'but', 'hope', 'to', 'see', 'all', 'applica
# ...

# %%
import re

# Decorator for handling file I/O and errors
def handler(func):
    def opener(incoming_file):
        try:
            with open(incoming_file) as file_ptr:
                f_content = file_ptr.read()
                result = func(f_content)
        except FileNotFoundError as error_msg:
            print(f'File {incoming_file} not found: {error_msg}')
        except ValueError as error_msg:
            print(f'Please enter a valid filename "{incoming_file}" and check if extension is "txt": {error_msg}')
        except Exception as error_msg:
            print(f'Error occurred: {error_msg}')
        else:
            print('Process executed successfully!')
        finally:
            file_ptr.close()
            print(f'File close status: {file_ptr.closed}')
            return result
    return opener

# Utility function to check for palindromes
def is_palindrome(word):
    word = word.lower()
    return word == word[::-1] and len(word) > 1

# Function to remove raw escape sequences and process the text
@handler
def fetch_palindrome_smartly(f_data):
    try:
        # Remove raw escape sequences (e.g., '\\n', '\\t')
        escape_characters = [r"\\n", r"\\t", r"\\r", r"\\b", r"\\f", r"\\a", r"\\v"]
        for escape in escape_characters:
            f_data = f_data.replace(escape, " ")  # Replace escape sequences with space

        # Split text by non-alphabetic characters
        words = re.split(r'[^a-zA-Z]+', f_data)
        print(words)
        # Filter palindromic words
        palindromic_words = [word for word in words if is_palindrome(word)]

    except Exception as error_msg:
        print(f'Error: {error_msg}')
    else:
        return palindromic_words


print(fetch_palindrome_smartly('testfile.txt'))
# Out:
# ['', 'nBuilding', 'on', 'Part', 'of', 'this', 'PSF', 'Grants', 'Program', 'Update', 'radar', 'level', 'kayak', 'civic', 'rotator', 'racecar', 'madam', 'refer', 'noon', 'pop', 'deed', 'peep', 'repaper', 'deed', 'rotor', 'stats', 'solos', 'tenet', 'deified', 'reviver', 'rotavator', 'we', 'are', 'pleased', 'to', 'share', 'updates', 'to', 'the', 'Grants', 'Workgroup', 'workgroup', 'Charter', 'We', 'have', 'outlined', 'all', 'the', 'changes', 'below', 'in', 'a', 'chart', 'but', 'there', 'are', 'a', 'couple', 'of', 'changes', 'that', 'we', 'd', 'like', 'to', 'highlight', 'to', 'grant', 'applicants', 'These', 'updates', 'in', 'particular', 'will', 'change', 'how', 'and', 'when', 'you', 'apply', 'and', 'hopefully', 'reduce', 'blockers', 'to', 'getting', 'those', 'applications', 'in', 'and', 'ready', 'for', 'review', 'Because', 'we', 'are', 'just', 'sharing', 'these', 'updates', 'we', 'are', 'happy', 'to', 'be', 'flexible', 'on', 'these', 'changes', 'but', 'hope', 'to', 'see', 'all', 'applica
# ...

# %%
import re

# Function to check for palindrome
def is_palindrome(word):
    word = word.lower()
    return word == word[::-1] and len(word) > 1  # Checking if the word is a palindrome

# Function to remove raw escape sequences and process the text
def fetch_palindrome_smartly(f_data):
    try:
        # Replace raw escape sequences with spaces
        f_data = f_data.replace(r'\n', ' ')  # Replace \n escape sequences with a space

        # Split the text into words using non-alphabetic characters as delimiters
        words = re.split(r'[^a-zA-Z]+', f_data)
        print(words)
        # Filter palindromic words
        palindromic_words = [word for word in words if is_palindrome(word)]

        return palindromic_words

    except Exception as error_msg:
        print(f'Error occurred: {error_msg}')
        return []

# Sample input text
text = '''\nBuilding, on Part 1 of this PSF Grants Program Update, radar level kayak civic rotator racecar madam refer noon pop deed peep repaper deed rotor stats solos tenet deified reviver rotavator we are pleased to share updates to the Grants Workgroup (workgroup) Charter. We have outlined all the changes below in a chart,but there are a couple of changes that we’d like to highlight to grant applicants. These updates in particular will change how and when you apply, and hopefully reduce blockers to getting those applications in and ready for review. Because we are just sharing these updates, we are happy to be flexible on these changes but hope to see all applicants adhere to the changes starting around January 2025.\n\nIncrease overall process time frame to 8 weeks (formerly 6 weeks). We want to be realistic about how long the process takes and we know that going over our projection can cause pain for applicants. We hope to turn around applications in 6 weeks in most cases, but planning for the extra two weeks can make a big difference for everyone involved!\nOur application form requires that you set the event date out to 6 weeks in advance. We will wait to update that to 8 weeks in advance until January 2025.\nIt’s important to note that this time frame begins only once all required information has been received, not exactly from the day the application is submitted. Make sure to check the email you provided on the application to see if the workgroup Chair has any questions regarding your request!\nAdd a statement of support for accessibility services. In line with the PSF’s mission to support and facilitate the growth of a diverse community, we are explicitly stating in the charter that we will consider funding accessibility services. For established events (have 2 or more events in the past with more than 200 participants at the last event), we are open to considering accessibility-related requests such as live captioning, sign language interpretation, or certified child care.\nTo review these tacocat types tacocat of requests, we will need sufficient documentation such as quotes, certifications, or any other relevant information.'''

# Call the function to process the text and find palindromes
palindromes = fetch_palindrome_smartly(text)
print(palindromes)
# Out:
# ['', 'Building', 'on', 'Part', 'of', 'this', 'PSF', 'Grants', 'Program', 'Update', 'radar', 'level', 'kayak', 'civic', 'rotator', 'racecar', 'madam', 'refer', 'noon', 'pop', 'deed', 'peep', 'repaper', 'deed', 'rotor', 'stats', 'solos', 'tenet', 'deified', 'reviver', 'rotavator', 'we', 'are', 'pleased', 'to', 'share', 'updates', 'to', 'the', 'Grants', 'Workgroup', 'workgroup', 'Charter', 'We', 'have', 'outlined', 'all', 'the', 'changes', 'below', 'in', 'a', 'chart', 'but', 'there', 'are', 'a', 'couple', 'of', 'changes', 'that', 'we', 'd', 'like', 'to', 'highlight', 'to', 'grant', 'applicants', 'These', 'updates', 'in', 'particular', 'will', 'change', 'how', 'and', 'when', 'you', 'apply', 'and', 'hopefully', 'reduce', 'blockers', 'to', 'getting', 'those', 'applications', 'in', 'and', 'ready', 'for', 'review', 'Because', 'we', 'are', 'just', 'sharing', 'these', 'updates', 'we', 'are', 'happy', 'to', 'be', 'flexible', 'on', 'these', 'changes', 'but', 'hope', 'to', 'see', 'all', 'applican
# ...

# %%
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def handler(func):
    def opener(incoming_file):
        try :
            with open(incoming_file) as file_ptr:
                f_content = file_ptr.read()
                result = func(f_content)
        except FileNotFoundError as error_msg :
            print('File {} is not found {} '.format(incoming_file,error_msg))
        except ValueError as error_msg :
            print('Please enter a valid filename {} and check if extension is "txt" or not error is {} '.format(incoming_file,error_msg))
        except Exception as error_msg :
            print('Error was - {} '.format(error_msg))
        else:
            print('Process executed successfully!')
        finally:
            file_ptr.close()
            print('Check file close status {} '.format(file_ptr.closed))
            return result
    return opener

#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def palindrome(words,palin_list):
    try :
        escape_characters = [
        r"\\",
        r"n",
        r"t",
        r"\'",
        r"\"",
        r"r",
        r"b",
        r"f",
        r"a",
        r"v",
        r"0",
        r"x",
        r"2",
        r"0",
        r"4",
        r"1",
        r"u",
        r"A",
        r"9",
        r"U",
        r"F",
        r"6"
        ]
        end_pos, words = 0, words + '--'
        length = len(words) - 1
        char = 0
        while char <= length:
            if not words[char].isalpha():
                if words[char] == "\\":
                    for i in range(len(words)):
                        if words[char+i] in escape_characters:
                            char+=1
                        else:
                            break
                if end_pos != char and char != length:
                    for cf in range(end_pos, char):
                        if words.lower().strip()[cf] == words.lower().strip()[end_pos:char][char - 1 - cf]:
                            continue
                        else:
                            break
                    else:
                        if len(words[end_pos:char]) > 1:
                            palin_list.append(words[end_pos:char])
                    end_pos = char + 1
                elif end_pos == char and not words[char].isalpha():
                    end_pos = char + 1
            char+=1
        return palin_list
    except Exception as error_msg:
        print('Error is {} '.format(error_msg))
    finally:
        return palin_list

#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

@handler
def fetch_palindrome(f_data):
    try :
        palin_list = []
        f_data = (lambda text : text.split('\n'))(f_data)
        f_data = list(map(lambda sub_text : sub_text.split(),f_data))
    except Exception as error_msg:
        print('ERROR IS --> {} '.format(error_msg))
    else:
        try :
            if isinstance(f_data,list):
                for scan in f_data:
                    if isinstance(scan,list):
                        for sub_scan in scan:
                            if isinstance(sub_scan,str):
                                palin_list = palindrome(sub_scan,palin_list)
                            else:
                                raise Exception('Something suspicious is included {} '.format(sub_scan))
                    elif isinstance(scan,str):
                        palin_list = palindrome(scan, palin_list)
                    else:
                        raise Exception('Something suspicious is included {} '.format(scan))
            else:
                raise Exception('Something suspicious is included {} '.format(f_data))
        except Exception as error_msg:
            print('Error is --> {} '.format(error_msg))
        else:
            return palin_list

#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

print(fetch_palindrome("break_code1.txt"))
#print(fetch_palindrome_smartly('large_obscure_text_with_palindromes.txt'))
# Out:
# Process executed successfully!
# Check file close status True
# ['madam', 'non']
